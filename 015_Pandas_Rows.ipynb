# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# slicing
df.iloc[0:11] # the last index in not include i.e n-1
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
df.loc[0:11] #last index is included
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df.iloc[100:111] #last element excluded in iloc.
# Out:
#         country  year  population continent  life_exp       gdp_cap
# 100  Bangladesh  1972    70759295      Asia    45.252    630.233627
# 101  Bangladesh  1977    80428306      Asia    46.923    659.877232
# 102  Bangladesh  1982    93074406      Asia    50.009    676.981866
# 103  Bangladesh  1987   103764241      Asia    52.819    751.979403
# 104  Bangladesh  1992   113704579      Asia    56.018    837.810164
# 105  Bangladesh  1997   123315288      Asia    59.412    972.770035
# 106  Bangladesh  2002   135656790      Asia    62.013   1136.390430
# 107  Bangladesh  2007   150448339      Asia    64.062   1391.253792
# 108     Belgium  1952     8730405    Europe    68.000   8343.105127
# 109     Belgium  1957     8989111    Europe    69.240   9714.960623
# 110     Belgium  1962     9218400    Europe    70.250  10991.206760

# %%
df.iloc[::500]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 500       Eritrea  1992     3668440    Africa    49.991   582.858510
# 1000     Mongolia  1972     1320500      Asia    53.754  1421.741975
# 1500       Taiwan  1952     8550362      Asia    58.500  1206.947913

# %%
df.loc[::500]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 500       Eritrea  1992     3668440    Africa    49.991   582.858510
# 1000     Mongolia  1972     1320500      Asia    53.754  1421.741975
# 1500       Taiwan  1952     8550362      Asia    58.500  1206.947913

# %%
df.iloc[::-1] # table reversal
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# ...           ...   ...         ...       ...       ...         ...
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1704 rows x 6 columns]

# %%
df.iloc[100:1000:100] # last ele. is excluded.
# Out:
#             country  year  population continent  life_exp       gdp_cap
# 100      Bangladesh  1972    70759295      Asia    45.252    630.233627
# 200    Burkina Faso  1992     8878303    Africa    50.260    931.752773
# 300        Colombia  1952    12350771  Americas    50.643   2144.115096
# 400  Czech Republic  1972     9862158    Europe    70.290  13108.453600
# 500         Eritrea  1992     3668440    Africa    49.991    582.858510
# 600       Guatemala  1952     3146381  Americas    42.023   2428.237769
# 700           India  1972   567000000      Asia    50.651    724.032527
# 800           Japan  1992   124329269      Asia    79.360  26824.895110
# 900           Libya  1952     1019729    Africa    42.723   2387.548060

# %%
df.loc[100:1000:100] # last ele. is included.
# Out:
#              country  year  population continent  life_exp       gdp_cap
# 100       Bangladesh  1972    70759295      Asia    45.252    630.233627
# 200     Burkina Faso  1992     8878303    Africa    50.260    931.752773
# 300         Colombia  1952    12350771  Americas    50.643   2144.115096
# 400   Czech Republic  1972     9862158    Europe    70.290  13108.453600
# 500          Eritrea  1992     3668440    Africa    49.991    582.858510
# 600        Guatemala  1952     3146381  Americas    42.023   2428.237769
# 700            India  1972   567000000      Asia    50.651    724.032527
# 800            Japan  1992   124329269      Asia    79.360  26824.895110
# 900            Libya  1952     1019729    Africa    42.723   2387.548060
# 1000        Mongolia  1972     1320500      Asia    53.754   1421.741975

# %% [markdown]
# # Adding the rows

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
dd = {'country':'India', 'year':2024, 'population':1.37, 'continent':'asia', 'life_exp':234.2, 'gdp_cap':1.3}

# %%
dd
# Out:
# {'country': 'India',
#  'year': 2024,
#  'population': 1.37,
#  'continent': 'asia',
#  'life_exp': 234.2,
#  'gdp_cap': 1.3}

# %%
# df.append(dd) # run this line and then comment line 
#  Can only append a dict if ignore_index=True

df.append(dd,ignore_index=True) #ignore_index=True : this things to tell us , ignore external indexe and align to default indexing.
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6816\2533697938.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(dd,ignore_index=True) #ignore_index=True : this things to tell us , ignore external indexe and align to default indexing.
#           country  year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972  13079460.00      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1700     Zimbabwe  1992  10704340.00    Africa    60.377  693.420786
# 1701     Zimbabwe  1997  11404948.00    Africa    46.809  792.449960
# ...

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[1704] = pd.Series(dd) #Because of default indexing(iloc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.iloc[1704] = pd.Series(dd)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:815, in _LocationIndexer.__setitem__(self, key, value)
#     813     key = com.apply_if_callable(key, self.obj)
#     814 indexer = self._get_setitem_indexer(key)
# --> 815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
#     818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1518, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1516 elif is_integer(i):
#    1517     if i >= len(ax):
# -> 1518         raise IndexError("iloc cannot enlarge its target object")
#    1519 elif isinstance(i, dict):
# ...

# %%
df.loc[1704] = pd.Series(dd) #loc is user define indexex.

# %%
df
# Out:
#           country  year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972  13079460.00      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1700     Zimbabwe  1992  10704340.00    Africa    60.377  693.420786
# 1701     Zimbabwe  1997  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007  12311143.00    Africa    43.487  469.709298
# 1704        India  2024         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]

# %%
dd1 = [{'country':'India', 'year':2024, 'population':1.37, 'continent':'asia', 'life_exp':234.2, 'gdp_cap':1.3},
      {'country':'America', 'year':2025, 'population':2.90, 'continent':'North-America', 'life_exp':255.2, 'gdp_cap':1},
       {'country':'Japan', 'year':2026, 'population':0.37, 'continent':'asia', 'life_exp':34.2, 'gdp_cap':2.0}]

# %%
df.append(dd1,ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6816\4272819369.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(dd1,ignore_index=True)
#           country  year   population      continent  life_exp     gdp_cap
# 0     Afghanistan  1952   8425333.00           Asia    28.801  779.445314
# 1     Afghanistan  1957   9240934.00           Asia    30.332  820.853030
# 2     Afghanistan  1962  10267083.00           Asia    31.997  853.100710
# 3     Afghanistan  1967  11537966.00           Asia    34.020  836.197138
# 4     Afghanistan  1972  13079460.00           Asia    36.088  739.981106
# ...           ...   ...          ...            ...       ...         ...
# 1703     Zimbabwe  2007  12311143.00         Africa    43.487  469.709298
# 1704        India  2024         1.37           asia   234.200    1.300000
# 1705        India  2024         1.37           asia   234.200    1.300000
# ...

# %%
df
# Out:
#           country  year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972  13079460.00      Asia    36.088  739.981106
# ...           ...   ...          ...       ...       ...         ...
# 1700     Zimbabwe  1992  10704340.00    Africa    60.377  693.420786
# 1701     Zimbabwe  1997  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007  12311143.00    Africa    43.487  469.709298
# 1704        India  2024         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]

# %%
df.loc[1705] = pd.Series(dd1)

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
#
# [1706 rows x 6 columns]

# %%
df.drop(1705)
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1700     Zimbabwe  1992.0  10704340.00    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
#
# [1706 rows x 6 columns]

# %% [markdown]
# # Remove duplicate

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
#
# [1706 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1705    False
# Length: 1706, dtype: bool

# %%
# using boolean masking
df[df.duplicated()] #there is no True value means no duplicates in the dataset
# Out:
# Empty DataFrame
# Columns: [country, year, population, continent, life_exp, gdp_cap]
# Index: []

# %%
dd1 = {'country':'India', 'year':2024, 'population':1.37, 'continent':'asia', 'life_exp':234.2, 'gdp_cap':1.3}

# %%
df.append(dd1,ignore_index=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6816\4272819369.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(dd1,ignore_index=True)
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# ...

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
#
# [1706 rows x 6 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, year, population, continent, life_exp, gdp_cap]
# Index: []

# %%
df.loc[1706] = pd.Series(dd1)

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
# 1706        India  2024.0         1.37      asia   234.200    1.300000
#
# [1707 rows x 6 columns]

# %%
df[df.duplicated()]
# Out:
#      country    year  population continent  life_exp  gdp_cap
# 1706   India  2024.0        1.37      asia     234.2      1.3

# %%
df.drop_duplicates() # All  duplicates removed.
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1704        India  2024.0         1.37      asia   234.200    1.300000
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
#
# [1706 rows x 6 columns]

# %%
df.drop_duplicates(keep='last',inplace=True)

# %%
df
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
# 1706        India  2024.0         1.37      asia   234.200    1.300000
#
# [1706 rows x 6 columns]

# %%
df.drop(2)
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# 5     Afghanistan  1977.0  14880372.00      Asia    38.438  786.113360
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
# 1706        India  2024.0         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]

# %%
df.drop(100)
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
# 1706        India  2024.0         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]

# %%
df.drop(1700,axis=0) #default axis = 0
# Out:
#           country    year   population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0   8425333.00      Asia    28.801  779.445314
# 1     Afghanistan  1957.0   9240934.00      Asia    30.332  820.853030
# 2     Afghanistan  1962.0  10267083.00      Asia    31.997  853.100710
# 3     Afghanistan  1967.0  11537966.00      Asia    34.020  836.197138
# 4     Afghanistan  1972.0  13079460.00      Asia    36.088  739.981106
# ...           ...     ...          ...       ...       ...         ...
# 1701     Zimbabwe  1997.0  11404948.00    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0  11926563.00    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0  12311143.00    Africa    43.487  469.709298
# 1705          NaN     NaN          NaN       NaN       NaN         NaN
# 1706        India  2024.0         1.37      asia   234.200    1.300000
#
# [1705 rows x 6 columns]
